# %% [markdown]
# ## machine learning is not just a simple algorithm which you can put anywhere and start getting results.It is process that starts with defining data,and ends with the some defined level of accuracy

# %% [markdown]
# ## chappie movie
# ## steps involed in machne learning
# ##### 1.Defining the problems(P,E,T)performance,experience,testing
# ##### 2.collecting the data
# ##### 3.Prepare the data
# ##### 4.split the data in training and testing
# ##### 5.algorithm selection
# ##### 6.Training the algorithm
# ##### 7.Evaluation of test data
# ##### 8.parameter tuning
# ##### 9.Start using your model....

# %% [markdown]
# ### pandas --data manipulation and analysis
# ### read_csv----- for csv comma seperated value
# ### read_excel---for excel
# ### matplotlib----data visuaization
# ### numpy-----multy dimention array
# ### seaborn-----visualization

# %% [markdown]
# # Three types of machine learning
# ### 1.supervisor learning
# ### 2. unsupervisor learning
# ### 3.rainforcement learning

# %% [markdown]
#                       machine leaning
#         ------------------------------------------
#         -                   -                     -
#     supervised         unsupervised          reinforcement
#
#     1.classification    1.clustering        software component learn to
#     2.regression        2.association       react to an environment

# %% [markdown]
# # algorithms

# %% [markdown]
# # supervised task driven
# ## 1.classfication
# #### example:
#             1. decision trees
#             2. bayesian network
#             3. support vector machine
#             4. random forest
#             5.neural networks
# ## 2.regression
# #### example:
#             1.simple linear regression model
#             2.lasso regression
#             3.logistic regression
#             4.multiple regression
#             5.boosting
# # unsupervised data driven
# ## clustering
# #### example:
#              1.k-means
#              2.mean-shift
#              3.gaussian mixture
#              4.EM-Clustering
#              5.Herarchical clustering

# %% [markdown]
# y=f(x)
# y is an dependent variable
# x is a independent variable
# y=mx+c or y=b1X+b0
# x is a independent variable
# m(or)b1 is slope
# c(or)b0 is intercept
# ## root mean square error is:
#             slope(b1)=E(x-(mean of x)(y-(mean of y))/E(x-(mean of x))^2
# ## predicted value:
#                       E(predicted mean of y)^2/E(predicted mean of y)^2

# %% [markdown]
# MSE cost function for linear regression......
#
# MSE(X,h(theta))=1/m summation(theta(transpose).x(i)-y(i))^2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Advertising.csv")
data.tail()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
data.drop("Unnamed: 0",axis=1,inplace=True)
data.tail()
# Out:
#         TV  radio  newspaper  sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4

# %%
x=data["TV"].values
print(x.shape)
print(x)
# Out:
# (200,)
# [230.1  44.5  17.2 151.5 180.8   8.7  57.5 120.2   8.6 199.8  66.1 214.7
#   23.8  97.5 204.1 195.4  67.8 281.4  69.2 147.3 218.4 237.4  13.2 228.3
#   62.3 262.9 142.9 240.1 248.8  70.6 292.9 112.9  97.2 265.6  95.7 290.7
#  266.9  74.7  43.1 228.  202.5 177.  293.6 206.9  25.1 175.1  89.7 239.9
#  227.2  66.9 199.8 100.4 216.4 182.6 262.7 198.9   7.3 136.2 210.8 210.7
#   53.5 261.3 239.3 102.7 131.1  69.   31.5 139.3 237.4 216.8 199.1 109.8
#   26.8 129.4 213.4  16.9  27.5 120.5   5.4 116.   76.4 239.8  75.3  68.4
#  213.5 193.2  76.3 110.7  88.3 109.8 134.3  28.6 217.7 250.9 107.4 163.3
#  197.6 184.9 289.7 135.2 222.4 296.4 280.2 187.9 238.2 137.9  25.   90.4
#   13.1 255.4 225.8 241.7 175.7 209.6  78.2  75.1 139.2  76.4 125.7  19.4
#  141.3  18.8 224.  123.1 229.5  87.2   7.8  80.2 220.3  59.6   0.7 265.2
#    8.4 219.8  36.9  48.3  25.6 273.7  43.  184.9  73.4 193.7 220.5 104.6
#   96.2 140.3 240.1 243.2  38.   44.7 280.7 121.  197.6 171.3 187.8   4.1
# ...

# %%
y=data["sales"]
print(y.shape)
y
# Out:
# (200,)
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
# 5       7.2
# 6      11.8
# 7      13.2
# 8       4.8
# 9      10.6
# 10      8.6
# 11     17.4
# 12      9.2
# 13      9.7
# 14     19.0
# 15     22.4
# 16     12.5
# 17     24.4
# 18     11.3
# 19     14.6
# 20     18.0
# 21     12.5
# 22      5.6
# 23     15.5
# 24      9.7
# 25     12.0
# 26     15.0
# 27     15.9
# 28     18.9
# 29     10.5
#        ...
# 170     8.4
# 171    14.5
# 172     7.6
# 173    11.7
# 174    11.5
# 175    27.0
# 176    20.2
# 177    11.7
# 178    11.8
# 179    12.6
# 180    10.5
# 181    12.2
# 182     8.7
# 183    26.2
# 184    17.6
# 185    22.6
# 186    10.3
# 187    17.3
# 188    15.9
# 189     6.7
# 190    10.8
# 191     9.9
# 192     5.9
# 193    19.6
# 194    17.3
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
x_mean=x.mean()
print("x-mean:",x_mean)
y_mean=np.mean(y)
print("y-mean:",y_mean)
# Out:
# x-mean: 147.0425
# y-mean: 14.022500000000003

# %%
# calculating error
n=len(x)
print(n)   #y=b1x+b0   b1-->slope,b0-->intercept
numer=0   
denom=0
for i in range(n):
    numer+=(x[i]-x_mean)*(y[i]-y_mean)
    denom+=(x[i]-x_mean)**2
b1=numer/denom
b0=y_mean-(b1*x_mean)
print("slope:",b1)
print("intercept:",b0)
# Out:
# 200
# slope: 0.04753664043301969
# intercept: 7.032593549127705

# %%
#y=mx+c
print("linear equation:y=[:.5]x+[:.4]".format(b1,b0))
# Out:
# linear equation:y=[:.5]x+[:.4]

# %%
y_predict=b1*x+b0
y_predict
# Out:
# array([17.97077451,  9.14797405,  7.85022376, 14.23439457, 15.62721814,
#         7.44616232,  9.76595037, 12.74649773,  7.44140866, 16.53041431,
#        10.17476548, 17.23871025,  8.16396559, 11.66741599, 16.73482186,
#        16.32125309, 10.25557777, 20.40940417, 10.32212907, 14.03474068,
#        17.41459582, 18.31779199,  7.6600772 , 17.88520856,  9.99412625,
#        19.52997632, 13.82557947, 18.44614092, 18.85970969, 10.38868036,
#        20.95607553, 12.39948025, 11.653155  , 19.65832525, 11.58185004,
#        20.85149492, 19.72012288, 10.58358059,  9.08142275, 17.87094757,
#        16.65876324, 15.44657891, 20.98935118, 16.86792445,  8.22576322,
#        15.35625929, 11.2966302 , 18.43663359, 17.83291826, 10.21279479,
#        16.53041431, 11.80527225, 17.31952254, 15.71278409, 19.52046899,
#        16.48763133,  7.37961102, 13.50708398, 17.05331735, 17.04856369,
#         9.57580381, 19.45391769, 18.4081116 , 11.91460652, 13.26464711,
# ...

# %%
# r2 score
n1=0
d1=0
for i in range(n):
    n1+=(y_predict[i]-y_mean)**2
    d1+=(y[i]-y_mean)**2
r2=1-n1/d1
print("r2 score:",r2)
# Out:
# r2 score: 0.38812494914993034

# %%
plt.scatter(x,y_predict)

# %%
plt.scatter(x,y_predict,label="linear wave",color="g")
plt.xlabel("x")
plt.ylabel("y_predict value")
plt.title("linear regression with model including")
plt.legend()

# %%
#sklearn   ---->to implement a algorithm
from sklearn.linear_model import LinearRegression

# %%
#x,y
data
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# 5      8.7   48.9       75.0    7.2
# 6     57.5   32.8       23.5   11.8
# 7    120.2   19.6       11.6   13.2
# 8      8.6    2.1        1.0    4.8
# 9    199.8    2.6       21.2   10.6
# 10    66.1    5.8       24.2    8.6
# 11   214.7   24.0        4.0   17.4
# 12    23.8   35.1       65.9    9.2
# 13    97.5    7.6        7.2    9.7
# 14   204.1   32.9       46.0   19.0
# 15   195.4   47.7       52.9   22.4
# 16    67.8   36.6      114.0   12.5
# 17   281.4   39.6       55.8   24.4
# 18    69.2   20.5       18.3   11.3
# 19   147.3   23.9       19.1   14.6
# 20   218.4   27.7       53.4   18.0
# 21   237.4    5.1       23.5   12.5
# 22    13.2   15.9       49.6    5.6
# 23   228.3   16.9       26.2   15.5
# 24    62.3   12.6       18.3    9.7
# ...

# %%
x=data["TV"].values.reshape(-1,1)
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
y=data["sales"].values.reshape(-1,1)
y
# Out:
# array([[22.1],
#        [10.4],
#        [ 9.3],
#        [18.5],
#        [12.9],
#        [ 7.2],
#        [11.8],
#        [13.2],
#        [ 4.8],
#        [10.6],
#        [ 8.6],
#        [17.4],
#        [ 9.2],
#        [ 9.7],
#        [19. ],
#        [22.4],
#        [12.5],
#        [24.4],
#        [11.3],
#        [14.6],
#        [18. ],
#        [12.5],
#        [ 5.6],
#        [15.5],
#        [ 9.7],
#        [12. ],
#        [15. ],
#        [15.9],
#        [18.9],
#        [10.5],
#        [21.4],
#        [11.9],
#        [ 9.6],
#        [17.4],
#        [ 9.5],
#        [12.8],
#        [25.4],
#        [14.7],
#        [10.1],
#        [21.5],
#        [16.6],
#        [17.1],
#        [20.7],
#        [12.9],
#        [ 8.5],
#        [14.9],
#        [10.6],
#        [23.2],
#        [14.8],
#        [ 9.7],
#        [11.4],
#        [10.7],
#        [22.6],
#        [21.2],
#        [20.2],
#        [23.7],
#        [ 5.5],
#        [13.2],
# ...

# %%
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.coef_
# Out:
# array([[0.04753664]])

# %%
reg.intercept_
# Out:
# array([7.03259355])

# %%
y_predict=reg.predict(x)
print(y_predict)
# Out:
# [[17.97077451]
#  [ 9.14797405]
#  [ 7.85022376]
#  [14.23439457]
#  [15.62721814]
#  [ 7.44616232]
#  [ 9.76595037]
#  [12.74649773]
#  [ 7.44140866]
#  [16.53041431]
#  [10.17476548]
#  [17.23871025]
#  [ 8.16396559]
#  [11.66741599]
#  [16.73482186]
#  [16.32125309]
#  [10.25557777]
#  [20.40940417]
#  [10.32212907]
#  [14.03474068]
#  [17.41459582]
#  [18.31779199]
#  [ 7.6600772 ]
#  [17.88520856]
#  [ 9.99412625]
#  [19.52997632]
#  [13.82557947]
#  [18.44614092]
#  [18.85970969]
#  [10.38868036]
#  [20.95607553]
#  [12.39948025]
#  [11.653155  ]
#  [19.65832525]
#  [11.58185004]
#  [20.85149492]
#  [19.72012288]
#  [10.58358059]
#  [ 9.08142275]
#  [17.87094757]
#  [16.65876324]
#  [15.44657891]
#  [20.98935118]
#  [16.86792445]
#  [ 8.22576322]
#  [15.35625929]
#  [11.2966302 ]
#  [18.43663359]
#  [17.83291826]
#  [10.21279479]
#  [16.53041431]
#  [11.80527225]
#  [17.31952254]
#  [15.71278409]
#  [19.52046899]
#  [16.48763133]
#  [ 7.37961102]
#  [13.50708398]
# ...

# %%
score=reg.score(x,y)
print(score)
# Out:
# 0.611875050850071

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y,c='m',label="before prediction")
plt.plot(x,y_predict,c='r',label="linearregression")
plt.xlabel("x")
plt.ylabel("y")
plt.title("linearregression model")
plt.legend(loc="best")
plt.show()

# %% [markdown]
# # polynomial ---->multiple degree ax2+bx+c

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
x1=np.random.rand(100,1)
y1=0.5*x1**2+x1*2+np.random.rand(100,1)
print(x1.shape)
print(y1)
print(x1.shape)
# Out:
# (100, 1)
# [[2.84667861]
#  [1.79599097]
#  [1.09375033]
#  [2.52482275]
#  [3.034172  ]
#  [2.41771963]
#  [1.33491902]
#  [1.12095837]
#  [3.02057906]
#  [0.43415607]
#  [1.07101846]
#  [2.25278494]
#  [1.66102018]
#  [2.23350734]
#  [2.58371268]
#  [1.76244214]
#  [1.33859417]
#  [2.19571646]
#  [2.5699717 ]
#  [0.85405997]
#  [1.48326811]
#  [3.03761806]
#  [1.64916178]
#  [2.64046781]
#  [1.00876384]
#  [0.760472  ]
#  [2.71918816]
#  [1.01229014]
#  [2.49717573]
#  [2.3786717 ]
#  [1.18377653]
#  [2.10351346]
#  [1.95795948]
#  [0.82101926]
#  [1.2674638 ]
#  [1.51858202]
#  [1.50873872]
#  [1.79631526]
#  [2.2705526 ]
#  [1.13053999]
#  [2.62045684]
#  [0.74606976]
#  [0.60791442]
#  [2.38105547]
#  [2.06905226]
#  [1.09148789]
#  [0.82682506]
#  [0.89493476]
#  [1.5696233 ]
#  [1.65831393]
#  [1.21807815]
#  [1.03420939]
#  [2.06644835]
#  [1.65836147]
#  [1.31050776]
#  [2.5997834 ]
#  [0.84566231]
#  [0.78299126]
#  [2.45782577]
#  [2.30558067]
#  [0.30991349]
# ...

# %%
print(y1.shape)
# Out:
# (100, 1)

# %%
plt.plot(x1,y1,'.')

# %%
poly=PolynomialFeatures()

# %%
x_poly=poly.fit_transform(x1)
x_poly
# Out:
# array([[1.00000000e+00, 8.86895643e-01, 7.86583882e-01],
#        [1.00000000e+00, 7.25124016e-01, 5.25804839e-01],
#        [1.00000000e+00, 8.35502390e-02, 6.98064243e-03],
#        [1.00000000e+00, 9.24715861e-01, 8.55099423e-01],
#        [1.00000000e+00, 9.16623090e-01, 8.40197890e-01],
#        [1.00000000e+00, 7.44097857e-01, 5.53681621e-01],
#        [1.00000000e+00, 3.42328069e-01, 1.17188507e-01],
#        [1.00000000e+00, 3.51169607e-01, 1.23320093e-01],
#        [1.00000000e+00, 9.39472075e-01, 8.82607781e-01],
#        [1.00000000e+00, 4.06740334e-03, 1.65437699e-05],
#        [1.00000000e+00, 6.22025279e-02, 3.86915448e-03],
#        [1.00000000e+00, 8.16736523e-01, 6.67058548e-01],
#        [1.00000000e+00, 5.72779190e-01, 3.28076001e-01],
#        [1.00000000e+00, 7.90112686e-01, 6.24278056e-01],
#        [1.00000000e+00, 6.89415026e-01, 4.75293078e-01],
#        [1.00000000e+00, 7.06156659e-01, 4.98657227e-01],
# ...

# %%
x1[0]
# Out:
# array([0.88689564])

# %%
x_poly[0]
# Out:
# array([1.        , 0.88689564, 0.78658388])

# %%
x1[1]
# Out:
# array([0.72512402])

# %%
x_poly[1]
# Out:
# array([1.        , 0.72512402, 0.52580484])

# %%
poly.fit(x_poly,y1)
# Out:
# PolynomialFeatures(degree=2, include_bias=True, interaction_only=False,
#                    order='C')

# %%
from sklearn.linear_model import LinearRegression
lin=LinearRegression()

# %%
lin.fit(x_poly,y1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
lin.intercept_
# Out:
# array([0.67282207])

# %%
lin.coef_
# Out:
# array([[0.        , 1.31350247, 1.00579041]])

# %%
y_predictions=lin.predict(x_poly)

# %%
plt.scatter(x1,y1,c='g',label="before polynomial")
plt.plot(x1,y_predictions,c='r',label="after polynomial linear regression")
plt.xlabel("x1")
plt.ylabel("y1")
plt.title("linear regression with polynomial features")
plt.legend('best')
plt.show()
