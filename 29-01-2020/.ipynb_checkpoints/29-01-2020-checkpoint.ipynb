# %%
from datetime import datetime

# %%
a=datetime.now()
print(a)
print(a.year)
print(a.month)
print(a.day)
print(a.hour)
# Out:
# 2020-01-29 13:53:27.397602
# 2020
# 1
# 29
# 13

# %%
from datetime import *
now=datetime.now()
print(now)
print('date now:{}-{}-{}'.format(now.day,now.month,now.year))
print('time now:{}-{}-{}'.format(now.hour,now.minute,now.second))
# Out:
# 2020-01-29 14:01:39.268205
# date now:29-1-2020
# time now:14-1-39

# %%
tdm=datetime.today()
print(tdm)
print('today date and time:',tdm)
# Out:
# 2020-01-29 14:01:40.017405
# today date and time: 2020-01-29 14:01:40.017405

# %%
td=date.today()
td
# Out:
# datetime.date(2020, 1, 29)

# %%
diff=datetime(2011,1,4)-datetime(2008,6,24,8,15)
diff
# Out:
# datetime.timedelta(days=923, seconds=56700)

# %%
diff=datetime(2011,1,4)-datetime(2008,6,24,8,15)
diff.seconds
# Out:
# 56700

# %%
diff.total_seconds()
# Out:
# 79803900.0

# %%
datetime(2011,12,26)+timedelta(206)
# Out:
# datetime.datetime(2012, 7, 19, 0, 0)

# %%
value='26 Dec 2003'
datetime

# %%
date=[datetime(2000,1,4),datetime(2013,3,15),datetime(2006,5,23),datetime(1999,4,6)]

# %%
import pandas as pd
import numpy as np
s=pd.Series(np.random.rand(4),index=date)
s
# Out:
# 2000-01-04    0.601967
# 2013-03-15    0.298018
# 2006-05-23    0.779048
# 1999-04-06    0.778832
# dtype: float64

# %%
ind=s.index[0]
ind
# Out:
# Timestamp('2000-01-04 00:00:00')

# %%
s[ind]
# Out:
# 0.07910087424546319

# %%
now=datetime.now()
print(now)
timestamp=datetime.timestamp(now)
print(timestamp)
# Out:
# 2020-01-29 14:29:21.104615
# 1580288361.104615

# %%
X=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2000',periods=1000))
X
# Out:
# 2000-01-01   -0.483594
# 2000-01-02    2.560384
# 2000-01-03   -1.045590
# 2000-01-04   -0.703308
# 2000-01-05   -0.661419
# 2000-01-06    2.215982
# 2000-01-07   -1.903002
# 2000-01-08    2.419585
# 2000-01-09    1.065943
# 2000-01-10    1.755689
# 2000-01-11   -0.040184
# 2000-01-12   -0.547696
# 2000-01-13   -0.606449
# 2000-01-14    0.390482
# 2000-01-15   -1.650312
# 2000-01-16    0.148268
# 2000-01-17   -0.137813
# 2000-01-18    0.027338
# 2000-01-19    0.110549
# 2000-01-20    0.881501
# 2000-01-21   -0.541950
# 2000-01-22    0.452313
# 2000-01-23   -1.622030
# 2000-01-24    0.393818
# 2000-01-25    0.997984
# 2000-01-26   -0.193920
# 2000-01-27    0.855497
# 2000-01-28   -0.734019
# 2000-01-29   -0.544158
# 2000-01-30    0.273025
#                 ...
# 2002-08-28   -0.060415
# 2002-08-29   -0.694700
# 2002-08-30    0.059746
# 2002-08-31    1.077979
# 2002-09-01   -2.692228
# 2002-09-02   -0.302333
# 2002-09-03    0.808917
# 2002-09-04   -0.663129
# 2002-09-05   -1.127141
# ...

# %%
X['2001']
# Out:
# 2001-01-01   -0.773058
# 2001-01-02   -1.219183
# 2001-01-03   -0.236270
# 2001-01-04   -2.563029
# 2001-01-05   -0.091587
# 2001-01-06    1.647139
# 2001-01-07    2.099914
# 2001-01-08    0.535912
# 2001-01-09    1.910706
# 2001-01-10    0.243377
# 2001-01-11   -0.380459
# 2001-01-12    0.544391
# 2001-01-13    0.531936
# 2001-01-14   -1.570304
# 2001-01-15   -1.025750
# 2001-01-16   -1.215691
# 2001-01-17   -0.269408
# 2001-01-18    1.647682
# 2001-01-19    1.626742
# 2001-01-20   -0.531623
# 2001-01-21    0.798128
# 2001-01-22    0.731049
# 2001-01-23   -0.614612
# 2001-01-24    1.586215
# 2001-01-25   -0.000612
# 2001-01-26    0.993460
# 2001-01-27   -0.382407
# 2001-01-28    0.303747
# 2001-01-29   -0.159883
# 2001-01-30   -0.206911
#                 ...
# 2001-12-02    1.506782
# 2001-12-03   -1.942733
# 2001-12-04   -0.041948
# 2001-12-05    0.207621
# 2001-12-06    1.201100
# 2001-12-07    1.177113
# 2001-12-08    2.519556
# 2001-12-09   -1.578073
# 2001-12-10    0.584762
# ...

# %%
X['2001-03']
# Out:
# 2001-03-01   -1.613729
# 2001-03-02    0.568287
# 2001-03-03   -0.156413
# 2001-03-04   -1.472259
# 2001-03-05   -1.593597
# 2001-03-06    0.120607
# 2001-03-07   -0.974577
# 2001-03-08    0.399367
# 2001-03-09    0.595628
# 2001-03-10   -0.099643
# 2001-03-11    0.097421
# 2001-03-12    0.761047
# 2001-03-13    2.115149
# 2001-03-14    0.290013
# 2001-03-15    0.063338
# 2001-03-16   -2.097897
# 2001-03-17   -0.516108
# 2001-03-18    0.034238
# 2001-03-19    1.228411
# 2001-03-20   -1.116149
# 2001-03-21    1.251817
# 2001-03-22   -0.586173
# 2001-03-23   -0.172494
# 2001-03-24    0.917535
# 2001-03-25   -1.086224
# 2001-03-26    2.254424
# 2001-03-27   -0.016965
# 2001-03-28    1.612285
# 2001-03-29    0.490563
# 2001-03-30    0.616620
# 2001-03-31   -0.727818
# Freq: D, dtype: float64

# %%
s
# Out:
# 2000-01-04    0.601967
# 2013-03-15    0.298018
# 2006-05-23    0.779048
# 1999-04-06    0.778832
# dtype: float64

# %%
s[datetime(2013,3,15):]
# Out:
# 2013-03-15    0.298018
# 2006-05-23    0.779048
# 1999-04-06    0.778832
# dtype: float64

# %%
pd.date_range('2000-1-1','2001-1-1',freq='BM')
# Out:
# DatetimeIndex(['2000-01-31', '2000-02-29', '2000-03-31', '2000-04-28',
#                '2000-05-31', '2000-06-30', '2000-07-31', '2000-08-31',
#                '2000-09-29', '2000-10-31', '2000-11-30', '2000-12-29'],
#               dtype='datetime64[ns]', freq='BM')

# %%
dates=pd.date_range('1/1/2019',periods=100,freq='W-WED')

# %%
df=pd.DataFrame(np.random.randn(100,4),index=dates,columns=['colorado','texas','new york','ohio'])
df
# Out:
#             colorado     texas  new york      ohio
# 2019-01-02 -0.311917  0.971495  0.798711  0.785233
# 2019-01-09 -0.015581  0.358422 -0.603429 -0.254169
# 2019-01-16  0.195316 -0.936188  0.077009 -0.307911
# 2019-01-23  0.402542 -0.923396 -1.817649  0.619317
# 2019-01-30  0.017821  0.750591 -0.923686 -0.571725
# 2019-02-06 -0.819707  0.638475 -0.212242 -1.474433
# 2019-02-13  0.588538 -0.671202 -0.802063 -0.155677
# 2019-02-20 -2.249322 -0.280558 -0.899692  0.718962
# 2019-02-27 -0.108940 -0.354851 -1.429018  0.808101
# 2019-03-06  0.544555  0.121000 -0.212983  0.356537
# 2019-03-13  1.289521 -0.365521 -0.097645 -0.607329
# 2019-03-20  0.303010 -1.951927  0.353849  0.369096
# 2019-03-27 -1.536045  0.411410  2.066946 -0.589682
# 2019-04-03  0.342512 -1.755784  0.810882 -0.434980
# 2019-04-10 -0.962919 -0.598691  0.588359  1.092905
# 2019-04-17 -1.247580 -1.342438 -0.104732  0.515413
# 2019-04-24 -0.079985  0.278168 -1.414468  1.123966
# ...

# %%
df['5-2019']
# Out:
#             colorado     texas  new york      ohio
# 2019-05-01  0.647492 -1.556341  0.442373  0.537496
# 2019-05-08 -0.721490 -0.097952 -1.701087  0.478909
# 2019-05-15 -0.510777 -1.806953  0.394145 -0.128520
# 2019-05-22  1.347351  1.853419  0.050392 -0.857293
# 2019-05-29  0.881617  1.925910  1.321336  0.102629
